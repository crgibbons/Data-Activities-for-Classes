# %% [markdown]
# # NESCAC Ice Hockey (M) Principal Component Analysis
# ## 2022-23 through 2025-26 standings and team stats

# %%
import pandas as pd
import glob

# Find all CSV files in the current folder
csv_files = glob.glob('*.csv')

# Assuming there are exactly 4 CSV files, load them into DataFrames and drop 'teams' column
df1 = pd.read_csv(csv_files[0]).drop(columns=['Team','Neutral','Neutral Att','Neutral Att Avg','All Att','All Att Avg','All'])
df2 = pd.read_csv(csv_files[1]).drop(columns=['Team','Neutral','Neutral Att','Neutral Att Avg','All Att','All Att Avg','All'])
df3 = pd.read_csv(csv_files[2]).drop(columns=['Team','Neutral','Neutral Att','Neutral Att Avg','All Att','All Att Avg','All'])
df4 = pd.read_csv(csv_files[3]).drop(columns=['Team','Neutral','Neutral Att','Neutral Att Avg','All Att','All Att Avg','All'])

# %%
# Split the 'GF-GA' column into 'GF' and 'GA' for each dataframe
for df in [df1, df2, df3, df4]:
    df[['GF', 'GA']] = df['GF-GA'].str.split(' - ', expand=True).astype(int)
    df.drop(columns=['GF-GA'], inplace=True)
for df in [df1, df2, df3, df4]:
    df[['AVGH', 'AVGV']] = df['AVG Score'].str.split(' - ', expand=True).astype(float)
    df.drop(columns=['AVG Score'], inplace=True)
for df in [df1, df2, df3, df4]:
    df[['Pen Num', 'Pen Min']] = df['Pen'].str.split(' - ', expand=True).astype(str)
    df.drop(columns=['Pen'], inplace=True)

# %%
for df in [df1, df2, df3, df4]:
    df['Pen Num'] = df['Pen Num'].str.replace('None', '0').astype(int)
    df['Pen Min'] = df['Pen Min'].str.replace(':00', '').astype(int)

# %%
df1.head()
# Out:
#    Standing  GP  Margin  AST  PTS  Shots  Shot%  Saves   Sav%  PPG  ...  \
# 0         6  25   -0.04   92  152    741   0.08    592  0.907   14  ...
# 1         4  26    1.46  132  220    728   0.12    698  0.933   17  ...
# 2         3  24   -0.21   94  158    663   0.10    676  0.907    8  ...
# 3         8  25   -0.64  109  180    728   0.10    709  0.891   11  ...
# 4         1  30    1.93  198  311   1058   0.11    671  0.924   30  ...
#
#    Home Att Avg  Away  Away Att  Away Att Avg   GF  GA  AVGH  AVGV  Pen Num  \
# 0           222    14      6314           451   60  61   2.4   2.4       83
# 1           573    11      4245           385   88  50   3.4   1.9       98
# 2           348    13      5497           422   64  69   2.7   2.9       93
# 3           268    13      4404           338   71  87   2.8   3.5      125
# 4           435    14     11060           790  113  55   3.8   1.8       97
#
#    Pen Min
# 0      169
# 1      207
# 2      189
# 3      272
# 4      197
#
# [5 rows x 23 columns]

# %%
# Compute sample mean for numeric columns in df1
means = df1.mean(numeric_only=True)
print("Sample Means:")
print(means)
# Out:
# Sample Means:
# Standing           5.500
# GP                25.900
# Margin             0.235
# AST              124.800
# PTS              201.000
# Shots            789.200
# Shot%              0.097
# Saves            700.100
# Sav%               0.910
# PPG               15.800
# SHG                1.400
# Home              12.500
# Home ATT        4373.500
# Home Att Avg     335.600
# Away              13.400
# Away Att        6241.200
# Away Att Avg     454.100
# GF                76.200
# GA                69.400
# AVGH               2.930
# AVGV               2.680
# Pen Num           99.800
# Pen Min          208.700
# dtype: float64

# %%
# Compute sample variance for numeric columns in df1
variances = df1.var(numeric_only=True)
print("\nSample Variances:")
print(variances)
# Out:
# Sample Variances:
# Standing        9.166667e+00
# GP              3.655556e+00
# Margin          8.657611e-01
# AST             1.078178e+03
# PTS             2.452667e+03
# Shots           1.592996e+04
# Shot%           2.011111e-04
# Saves           7.136767e+03
# Sav%            1.953333e-04
# PPG             4.084444e+01
# SHG             2.266667e+00
# Home            2.944444e+00
# Home ATT        8.284606e+06
# Home Att Avg    3.623604e+04
# Away            2.488889e+00
# Away Att        8.301814e+06
# Away Att Avg    2.719166e+04
# GF              2.906222e+02
# GA              2.224889e+02
# AVGH            2.734444e-01
# AVGV            3.528889e-01
# Pen Num         1.597333e+02
# Pen Min         9.009000e+02
# dtype: float64

# %%
# Compute the covariance matrix for df1
cov_matrix = df1.cov()
print("Covariance Matrix:")
print(cov_matrix)
# Out:
# Covariance Matrix:
#                  Standing           GP       Margin           AST  \
# Standing         9.166667    -0.500000    -2.338333    -49.222222
# GP              -0.500000     3.655556     0.765000     51.422222
# Margin          -2.338333     0.765000     0.865761     22.234444
# AST            -49.222222    51.422222    22.234444   1078.177778
# PTS            -80.777778    75.000000    35.186667   1620.111111
# Shots         -140.555556   203.244444    65.213333   3753.377778
# Shot%           -0.027222     0.003000     0.009139      0.227111
# Saves          188.055556    50.900000   -38.165000   -200.644444
# Sav%            -0.014667     0.007222     0.008094      0.097778
# PPG             -5.666667    11.200000     3.586667    189.288889
# SHG              0.333333    -0.622222    -0.295556     -5.133333
# Home            -2.500000     2.055556     1.317222     39.444444
# Home ATT     -2413.277778  2763.388889  1491.086111  38145.222222
# Home Att Avg  -114.777778   151.955556    74.681111   1771.244444
# Away             2.000000     1.600000    -0.552222     11.977778
# Away Att       965.666667  4497.133333   114.943333  52312.155556
# Away Att Avg    -2.166667   265.344444    27.208333   3187.577778
# GF             -31.555556    23.577778    12.952222    541.933333
# GA              32.444444     0.266667   -10.823333    -88.133333
# AVGH            -1.183333     0.447778     0.411833     14.684444
# AVGV             1.244444    -0.324444    -0.481556     -8.004444
# Pen Num         14.000000     5.644444    -3.006667     69.177778
# Pen Min         38.277778     6.300000    -8.559444     44.600000
#
#                        PTS          Shots      Shot%         Saves       Sav%  \
# Standing        -80.777778    -140.555556  -0.027222    188.055556  -0.014667
