# %% [markdown]
# # SmolLM Text Generation Quickstart
#
# This notebook demonstrates synthetic text generation using a lightweight instruction-tuned language model:
#
# **HuggingFaceTB/SmolLM2-135M-Instruct**
#
# We will:
#
# - load the tokenizer and model
# - generate text from prompts
# - experiment with sampling parameters

# %%
import os
from huggingface_hub import login

login(token=os.environ["HF_TOKEN"])
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ## Import libraries

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# %% [markdown]
# ## Load model and tokenizer
#
# The first time this runs, the model will download.

# %%
model_name = "HuggingFaceTB/SmolLM2-135M-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float32
)
# Out:
# config.json:   0%|          | 0.00/861 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/655 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/269M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/272 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %% [markdown]
# ## Define a helper function for text generation

# %%
def generate_text(prompt, max_tokens=200, temperature=0.7):
    messages = [{"role": "user", "content": prompt}]

    formatted = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer([formatted], return_tensors="pt").to(model.device)

    outputs = model.generate(
        **inputs,
        max_new_tokens=max_tokens,
        temperature=temperature,
        do_sample=True
    )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %% [markdown]
# ## Example: synthetic news article

# %%
prompt = "Write a short fictional newspaper article about a mathematician discovering a paradox in voting systems."

print(generate_text(prompt))
# Out:
# system
# You are a helpful AI assistant named SmolLM, trained by Hugging Face
# user
# Write a short fictional newspaper article about a mathematician discovering a paradox in voting systems.
# assistant
# The mathematician, a brilliant and sometimes enigmatic figure, had been staring at a peculiar voting system for years. At first, it seemed like a simple yet elegant approach to fair and fair-minded elections. However, as he delved deeper, he realized that the system was not truly fair, and that the way it was structured was a paradox.
#
# The voting system, known as "The Voter's Choice," was an infinite regress, where every citizen had their own vote. But when the first candidate had a majority vote, every citizen would have to choose their own candidate. Now, the voting system was not just a matter of the number of votes cast, but also the direction each candidate would move, from being in the lead to being the one to win.
#
# What if the voting system made every citizen a winner, but also a loser? How could it be fair? The mathematician, a proponent of the system, pondered this question. Did it make sense? Did the

# %% [markdown]
# ## Example: mathematical exposition

# %%
prompt = "Explain in simple terms what an eigenvector is and why it matters."

print(generate_text(prompt))
# Out:
# system
# You are a helpful AI assistant named SmolLM, trained by Hugging Face
# user
# Explain in simple terms what an eigenvector is and why it matters.
# assistant
# An eigenvector is a vector that, when multiplied by itself, results in a non-zero value. In simpler terms, imagine a set of numbers that you're trying to get rid of. For example, if you have a set of numbers 1, 2, 3, 4, 5, and add them up, the result would be 10, not 1. The number 10 is an eigenvalue, meaning it's a quantity that's being "rescaled" or "reversed" by itself when multiplied by itself.
#
# When you have an eigenvector, you're essentially saying that the eigenvalue is the "smallest" or "smallest" part of the eigenvector, and the other eigenvectors are the "largest" or "largest" parts of the eigenvector. This means that the eigenvector is a "smaller" quantity than the other eigenvectors.
#
# Eigenvectors play a crucial role in understanding

# %% [markdown]
# ## Experiment with temperature
#
# Higher temperature → more creative output
#
# Lower temperature → more deterministic output

# %%
prompt = "Is a dog a good pet?"

print(generate_text(prompt, temperature=1.0))
# Out:
# system
# You are a helpful AI assistant named SmolLM, trained by Hugging Face
# user
# Is a dog a good pet?
# assistant
# That depends on the context of your house, the dogs you have, and your needs. Dogs can provide a great form of companionship, especially if you live in a big house or have a lot of strangers in your neighborhood. They are sociable, easy to manage, and can be very loyal to their human families. However, depending on the breed and the owner's style, different breeds might be happier in their new home. Would you like to know about a specific one?

# %% [markdown]
# ## Try your own prompt

# %%
prompt = "Describe Ayn Rand's philosophy of Objectivism in a single sentence."

print(generate_text(prompt, temperature=1.0)) #1, 10, 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 prompt = "Describe Ayn Rand's philosophy of Objectivism in a single sentence."
# ----> 3 print(generate_text(prompt, temperature=1.0)) #1, 10, 100
#
# NameError: name 'generate_text' is not defined
